# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()
plt.style.use('fivethirtyeight')

data = pd.read_csv('MSFT (1).csv')

# %%
data.head(5)
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2020-08-13  209.440002  211.350006  208.149994  208.699997  206.698624
# 1  2020-08-14  208.759995  209.589996  207.509995  208.899994  206.896698
# 2  2020-08-17  209.600006  211.190002  208.919998  210.279999  208.263489
# 3  2020-08-18  210.529999  212.360001  209.210007  211.490005  209.461884
# 4  2020-08-19  211.490005  212.100006  209.250000  209.699997  208.191086
#
#      Volume
# 0  22588900
# 1  17958900
# 2  20184800
# 3  21336200
# 4  27627600

# %%
plt.figure(figsize = (8,6))
plt.plot(data["Close"])
plt.xlabel("Date")
plt.ylabel("Close")
# Out:
# Text(0, 0.5, 'Close')

# %%
sns.heatmap(data.corr(), cmap = "YlGnBu")
# Out:
# <AxesSubplot:>

# %%
x = data[["Open", "High", "Low"]]
y = data["Close"]
x = x.to_numpy()
y = y.to_numpy()
y = y.reshape(-1,1)

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size = 0.20, random_state = 42)

# %%
from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor()
model.fit(xtrain, ytrain)
ypred = model.predict(xtest)
data = pd.DataFrame(data = {"Predicted Rate": ypred})
print(data.head(5))
# Out:
#    Predicted Rate
# 0      257.380005
# 1      216.440002
# 2      225.529999
# 3      260.739990
# 4      237.130005
