# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/movies_metadata.csv')
df.head(5)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# ...

# %%
# Write a Pandas program to get the information of the DataFrame (movies_metadata.csv file) including data types and memory usage.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget                 45466 non-null  object
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   45463 non-null  object
#  13  production_countries   45463 non-null  object
# ...

# %%
# Write a Pandas program to count the number of rows and columns of the DataFrame
df.describe()
# Out:
#             revenue       runtime  vote_average    vote_count
# count  4.546000e+04  45203.000000  45460.000000  45460.000000
# mean   1.120935e+07     94.128199      5.618207    109.897338
# std    6.433225e+07     38.407810      1.924216    491.310374
# min    0.000000e+00      0.000000      0.000000      0.000000
# 25%    0.000000e+00     85.000000      5.000000      3.000000
# 50%    0.000000e+00     95.000000      6.000000     10.000000
# 75%    0.000000e+00    107.000000      6.800000     34.000000
# max    2.787965e+09   1256.000000     10.000000  14075.000000

# %%
df.shape
# Out:
# (45466, 24)

# %%
# Write a Pandas program to get the columns of the DataFrame
df.columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %%
# Write a Pandas program to get the details of the third movie of the DataFrame

third_movie = df.iloc[2]
print(third_movie)
# Out:
# adult                                                                False
# belongs_to_collection    {'id': 119050, 'name': 'Grumpy Old Men Collect...
# budget                                                                   0
# genres                   [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# homepage                                                               NaN
# id                                                                   15602
# imdb_id                                                          tt0113228
# original_language                                                       en
# original_title                                            Grumpier Old Men
# overview                 A family wedding reignites the ancient feud be...
# popularity                                                         11.7129
# poster_path                               /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg
# ...

# %%
# Write a Pandas program to get the details of the columns title and genres of the DataFrame

result = df[['title', 'genres']]
result
# Out:
#                              title  \
# 0                        Toy Story
# 1                          Jumanji
# 2                 Grumpier Old Men
# 3                Waiting to Exhale
# 4      Father of the Bride Part II
# ...                            ...
# 45461                       Subdue
# 45462          Century of Birthing
# 45463                     Betrayal
# 45464             Satan Triumphant
# 45465                     Queerama
#
#                                                   genres
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                         [{'id': 35, 'name': 'Comedy'}]
# ...                                                  ...
# 45461  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45462                      [{'id': 18, 'name': 'Drama'}]
# ...

# %%
# Write a Python Pandas program to get the details of the movie with title 'Grumpier Old Men

title = df.set_index('title')
result = title.loc["Grumpier Old Men"]
result
# Out:
# adult                                                                False
# belongs_to_collection    {'id': 119050, 'name': 'Grumpy Old Men Collect...
# budget                                                                   0
# genres                   [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# homepage                                                               NaN
# id                                                                   15602
# imdb_id                                                          tt0113228
# original_language                                                       en
# original_title                                            Grumpier Old Men
# overview                 A family wedding reignites the ancient feud be...
# popularity                                                         11.7129
# poster_path                               /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg
# ...

# %%
# Write a Pandas program to get the details of fifth movie of the DataFrame.

result = df.iloc[4]
print(result)
# Out:
# adult                                                                False
# belongs_to_collection    {'id': 96871, 'name': 'Father of the Bride Col...
# budget                                                                   0
# genres                                      [{'id': 35, 'name': 'Comedy'}]
# homepage                                                               NaN
# id                                                                   11862
# imdb_id                                                          tt0113041
# original_language                                                       en
# original_title                                 Father of the Bride Part II
# overview                 Just when George Banks has recovered from his ...
# popularity                                                        8.387519
# poster_path                               /e64sOI48hQXyru7naBFyssKFxVd.jpg
# ...

# %%
# Write a Pandas program to create a smaller dataframe with a subset of all features.

smaller_dataframe = df[['title', 'release_date', 'budget', 'revenue', 'runtime']]
print(smaller_dataframe.head(5))
# Out:
#                          title release_date    budget      revenue  runtime
# 0                    Toy Story   1995-10-30  30000000  373554033.0     81.0
# 1                      Jumanji   1995-12-15  65000000  262797249.0    104.0
# 2             Grumpier Old Men   1995-12-22         0          0.0    101.0
# 3            Waiting to Exhale   1995-12-22  16000000   81452156.0    127.0
# 4  Father of the Bride Part II   1995-02-10         0   76578911.0    106.0

# %%
# Write a Pandas program to display the first 10 rows of the DataFrame.

df.head(10)
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# 5  False                                                NaN  60000000
# 6  False                                                NaN  58000000
# 7  False                                                NaN         0
# 8  False                                                NaN  35000000
# 9  False  {'id': 645, 'name': 'James Bond Collection', '...  58000000
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# ...

# %%
# Write a Pandas program to sort the DataFrame based on release_date.

result = df.sort_values('release_date')
result.head(5)
# Out:
#                                                    adult  \
# 19730                                 - Written by Ørnås
# 29503   Rune Balot goes to a casino connected to the ...
# 34940                                              False
# 34937                                              False
# 41602                                              False
#
#       belongs_to_collection                            budget  \
# 19730              0.065736  /ff9qCepilowshEtG2GYWwzt2bs4.jpg
# 29503              1.931659  /zV8bHuSL6WXoD6FWogP9j4x80bL.jpg
# 34940                   NaN                                 0
# 34937                   NaN                                 0
# 41602                   NaN                                 0
#
#                                                   genres  \
# 19730  [{'name': 'Carousel Productions', 'id': 11176}...
# 29503  [{'name': 'Aniplex', 'id': 2883}, {'name': 'Go...
# 34940                [{'id': 99, 'name': 'Documentary'}]
# ...

# %%
# Write a Pandas program to access those movies,released after 1995-01-01.

smaller_dataframe = df[['title', 'release_date', 'budget', 'revenue', 'runtime']]
result = smaller_dataframe[smaller_dataframe['release_date']>'1995-01-01']
print(result.head(5))
# Out:
#                          title release_date    budget      revenue  runtime
# 0                    Toy Story   1995-10-30  30000000  373554033.0     81.0
# 1                      Jumanji   1995-12-15  65000000  262797249.0    104.0
# 2             Grumpier Old Men   1995-12-22         0          0.0    101.0
# 3            Waiting to Exhale   1995-12-22  16000000   81452156.0    127.0
# 4  Father of the Bride Part II   1995-02-10         0   76578911.0    106.0

# %%
# Write a Pandas program to sort movies on runtime in descending order.

result = smaller_dataframe.sort_values('runtime', ascending=False)
result
# Out:
#                                 title release_date budget  revenue  runtime
# 24178                      Centennial   1978-10-01      0      0.0   1256.0
# 40938                        Baseball   1994-09-18      0      0.0   1140.0
# 19965                            Jazz   2001-01-09      0      0.0   1140.0
# 13767           Berlin Alexanderplatz   1980-08-28      0      0.0    931.0
# 13953  Heimat: A Chronicle of Germany   1984-09-16      0      0.0    925.0
# ...                               ...          ...    ...      ...      ...
# 45246                 Villa Henriette   2004-12-02      0      0.0      NaN
# 45310         Między nami dobrze jest   2014-08-01      0      0.0      NaN
# 45313                 Ostatni dzwonek   1989-10-27      0      0.0      NaN
# 45377   Simbad e il califfo di Bagdad   1973-07-22      0      0.0      NaN
# 45410                           Aprel          NaN      0      0.0      NaN
#
# [45466 rows x 5 columns]

# %%
# Write a Pandas program to get those movies whose revenue more than 2 million 

smaller_dataframe = df[['title', 'release_date', 'budget', 'revenue', 'runtime']]

result = smaller_dataframe[smaller_dataframe['revenue'] > 2000000 ]
print(result)
# Out:
#                              title release_date    budget      revenue  \
# 0                        Toy Story   1995-10-30  30000000  373554033.0
# 1                          Jumanji   1995-12-15  65000000  262797249.0
# 3                Waiting to Exhale   1995-12-22  16000000   81452156.0
# 4      Father of the Bride Part II   1995-02-10         0   76578911.0
# 5                             Heat   1995-12-15  60000000  187436818.0
# ...                            ...          ...       ...          ...
# 45139              The Emoji Movie   2017-07-28  50000000   66913939.0
# 45167                   Wind River   2017-08-03  11000000  184770205.0
# 45238                       Sahara   2017-02-01         0    7800000.0
# 45248                       Baasha   1995-01-15         0   15000000.0
# 45250             Sivaji: The Boss   2007-06-14  12000000   19000000.0
#
#        runtime
# 0         81.0
# 1        104.0
# 3        127.0
# 4        106.0
# 5        170.0
# ...        ...
# ...

# %%
# Write a Pandas program to get the longest runtime and shortest runtime.

small_df = df[['title', 'runtime']]
run_time = small_df['runtime']

print(run_time.max())
print(run_time.min())
# Out:
# 1256.0
# 0.0

# %%
# Write a Pandas program to calculate the number of votes garnered by the 70% movie.

result = df['vote_count'].quantile(0.70)
print(result)
# Out:
# 25.0
